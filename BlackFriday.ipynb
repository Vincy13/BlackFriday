# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
# %matplotlib inline
from sklearn import tree
from sklearn.linear_model import LinearRegression
from sklearn import datasets
from pandas import Series, DataFrame
from matplotlib import pyplot as plt

# %%
train=pd.read_csv("/home/vincy/Downloads/BlackFriday/train.csv")
test=pd.read_csv("/home/vincy/Downloads/BlackFriday/test.csv")
a1=test['User_ID']
b1=test['Product_ID']

# %%
train.head(20)
# Out:
#     User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0   1000001  P00069042      F   0-17          10             A
# 1   1000001  P00248942      F   0-17          10             A
# 2   1000001  P00087842      F   0-17          10             A
# 3   1000001  P00085442      F   0-17          10             A
# 4   1000002  P00285442      M    55+          16             C
# 5   1000003  P00193542      M  26-35          15             A
# 6   1000004  P00184942      M  46-50           7             B
# 7   1000004  P00346142      M  46-50           7             B
# 8   1000004   P0097242      M  46-50           7             B
# 9   1000005  P00274942      M  26-35          20             A
# 10  1000005  P00251242      M  26-35          20             A
# 11  1000005  P00014542      M  26-35          20             A
# 12  1000005  P00031342      M  26-35          20             A
# 13  1000005  P00145042      M  26-35          20             A
# ...

# %%
train.describe()
train.shape
# Out:
# (550068, 12)

# %%
train['Product_Category_2'].fillna(train['Product_Category_2'].mean(), inplace=True)
test['Product_Category_2'].fillna(test['Product_Category_2'].mean(), inplace=True)

# %%
train['Product_Category_3'].fillna(train['Product_Category_3'].mean(), inplace=True)
test['Product_Category_3'].fillna(test['Product_Category_3'].mean(), inplace=True)

# %%
train.describe(), test.describe()
# Out:
# (            User_ID     Occupation  Marital_Status  Product_Category_1  \
#  count  5.500680e+05  550068.000000   550068.000000       550068.000000
#  mean   1.003029e+06       8.076707        0.409653            5.404270
#  std    1.727592e+03       6.522660        0.491770            3.936211
#  min    1.000001e+06       0.000000        0.000000            1.000000
#  25%    1.001516e+06       2.000000        0.000000            1.000000
#  50%    1.003077e+06       7.000000        0.000000            5.000000
#  75%    1.004478e+06      14.000000        1.000000            8.000000
#  max    1.006040e+06      20.000000        1.000000           20.000000
#
#         Product_Category_2  Product_Category_3       Purchase
#  count       550068.000000       550068.000000  550068.000000
#  mean             9.842329           12.668243    9263.968713
#  std              4.207852            2.271830    5023.065394
#  min              2.000000            3.000000      12.000000
# ...

# %%
train.Gender.unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
#train['Gender'].replace(('M','F'),(0,1), inplace=True)

# %%
#train.Gender.unique()

# %%
train.City_Category.unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
train.Stay_In_Current_City_Years.unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
#train['Stay_In_Current_City_Years'].replace(('0','1'),(0), inplace=True)

# %%
#train['Stay_In_Current_City_Years'].replace(('2','3','4+'),(1), inplace=True)

# %%
#ltrain.Stay_In_Current_City_Years.unique()

# %%
train.head(10)
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042      F   0-17          10             A
# 1  1000001  P00248942      F   0-17          10             A
# 2  1000001  P00087842      F   0-17          10             A
# 3  1000001  P00085442      F   0-17          10             A
# 4  1000002  P00285442      M    55+          16             C
# 5  1000003  P00193542      M  26-35          15             A
# 6  1000004  P00184942      M  46-50           7             B
# 7  1000004  P00346142      M  46-50           7             B
# 8  1000004   P0097242      M  46-50           7             B
# 9  1000005  P00274942      M  26-35          20             A
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# ...

# %%
train.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
train.Age.unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
mylist=list(train.select_dtypes(include=['object']).columns)
mylist.remove('Product_ID')

mylist1=list(test.select_dtypes(include=['object']).columns)
mylist1.remove('Product_ID')

# %%
mylist, mylist1
# Out:
# (['Gender', 'Age', 'City_Category', 'Stay_In_Current_City_Years'],
#  ['Gender', 'Age', 'City_Category', 'Stay_In_Current_City_Years'])

# %%
dummies=pd.get_dummies(train[mylist], prefix=mylist)
train.drop(mylist, axis=1, inplace=True)
train=pd.concat([train,dummies], axis=1)

dummies1=pd.get_dummies(test[mylist1], prefix=mylist1)
test.drop(mylist1, axis=1, inplace=True)
test=pd.concat([test,dummies1], axis=1)

# %%
train.head(30), test.head()
# Out:
# (    User_ID Product_ID  Occupation  Marital_Status  Product_Category_1  \
#  0   1000001  P00069042          10               0                   3
#  1   1000001  P00248942          10               0                   1
#  2   1000001  P00087842          10               0                  12
#  3   1000001  P00085442          10               0                  12
#  4   1000002  P00285442          16               0                   8
#  5   1000003  P00193542          15               0                   1
#  6   1000004  P00184942           7               1                   1
#  7   1000004  P00346142           7               1                   1
#  8   1000004   P0097242           7               1                   1
#  9   1000005  P00274942          20               1                   8
#  10  1000005  P00251242          20               1                   5
#  11  1000005  P00014542          20               1                   8
# ...

# %%
train.shape, test.shape
# Out:
# ((550068, 25), (233599, 24))

# %%
Y=train['Purchase']

# %%
a=test['User_ID']
X=train.drop(['User_ID'], axis=1)
test=test.drop(['User_ID'], axis=1)

# %%
b=test['Product_ID']
X=X.drop(['Product_ID'], axis=1)

# %%
test=test.drop(['Product_ID'], axis=1)

# %%
X=X.drop(['Purchase'], axis=1)

# %%
X.head()
# Out:
#    Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# 0          10               0                   3            9.842329
# 1          10               0                   1            6.000000
# 2          10               0                  12            9.842329
# 3          10               0                  12           14.000000
# 4          16               0                   8            9.842329
#
#    Product_Category_3  Gender_F  Gender_M  Age_0-17  Age_18-25  Age_26-35  \
# 0           12.668243         1         0         1          0          0
# 1           14.000000         1         0         1          0          0
# 2           12.668243         1         0         1          0          0
# 3           12.668243         1         0         1          0          0
# 4           12.668243         0         1         0          0          0
#
#                ...                Age_51-55  Age_55+  City_Category_A  \
# ...

# %%
x_train, x_test, y_train, y_test=train_test_split(X,Y,train_size=0.70,test_size=0.30)

# %%
model=LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pred=model.predict(x_test)

# %%
from math import sqrt

# %%
mse=np.mean((pred-y_test)**2)

# %%
rmse=sqrt(mse)
rmse
# Out:
# 4682.400010107799

# %%
from sklearn.feature_selection import RFE
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor

# %%
model1=RandomForestRegressor(n_estimators=1000, max_depth=7)

# %%
model1.fit(x_train, y_train)

# %%
pred1=model1.predict(x_test)

# %%
rmse1=sqrt(np.mean((pred1-y_test)**2))
rmse1

# %%
#Gives the second best rmse of 2946 with gini and maxdep=10
model2 = tree.DecisionTreeClassifier(criterion='gini')
model2 = tree.DecisionTreeRegressor(max_depth=10)
model2.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=10, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
pred2=model2.predict(x_test)

# %%
rmse2=sqrt(np.mean((pred2-y_test)**2))
rmse2
# Out:
# 2946.3445464836964

# %%
test.head()
# Out:
#    Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# 0           7               1                   1                11.0
# 1          17               0                   3                 5.0
# 2           1               1                   5                14.0
# 3           1               1                   4                 9.0
# 4           1               0                   4                 5.0
#
#    Product_Category_3  Gender_F  Gender_M  Age_0-17  Age_18-25  Age_26-35  \
# 0           12.669454         0         1         0          0          0
# 1           12.669454         0         1         0          0          1
# 2           12.669454         1         0         0          0          0
# 3           12.669454         1         0         0          0          0
# 4           12.000000         1         0         0          0          1
#
#                ...                Age_51-55  Age_55+  City_Category_A  \
# ...

# %%
train.shape
# Out:
# (550068, 12)

# %%
predicted=model2.predict(test)

# %%
outdf=pd.DataFrame({"User_ID":a,"Product_ID":b,"Purchase":predicted})
outdf.to_csv("BlackFriday.csv")

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline 
from sklearn import preprocessing 
from sklearn.metrics import mean_squared_error 



## removing id variables 

# finally building model using tpot library
from tpot import TPOTRegressor
#X_train, X_test, y_train, y_test = train_test_split(X, y,
#train_size=0.75, test_size=0.25)

tpot = TPOTRegressor(generations=15, population_size=100, verbosity=2)
tpot.fit(x_train, y_train)
print(tpot.score(x_test, y_test))
tpot.export('genetic.py')
# Out:
# Optimization Progress:   1%|          | 16/1600 [05:25<20:44:56, 47.16s/pipeline]

# %%
tpot_pred = tpot.predict(test)
#sub1 = pd.DataFrame(data=tpot_pred)
#sub1.index = np.arange(0, len(test)+1)

#sub1.to_csv('tpot.csv',index=False)

outdf=pd.DataFrame({"User_ID":a,"Product_ID":b,"Purchase":predicted})
outdf.to_csv("BlackFridayGA.csv")

# %%
from sklearn.ensemble import GradientBoostingRegressor
from math import sqrt

# %%
#Gives the best MSE-2843.46 with 100, 0.1, 10
clf=GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=10)
clf.fit(x_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.1, loss='ls', max_depth=10, max_features=None,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=1,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=100, presort='auto', random_state=None,
#              subsample=1.0, verbose=0, warm_start=False)

# %%
predict3=clf.predict(x_test)

# %%
rmse3=sqrt(np.mean((predict3-y_test)**2))
rmse3
# Out:
# 2843.436622576278

# %%
clf.score(x_test, y_test)
# Out:
# 0.6790188228370602

# %%
test.head()
# Out:
#    Occupation  Marital_Status  Product_Category_1  Product_Category_2  \
# 0           7               1                   1                11.0
# 1          17               0                   3                 5.0
# 2           1               1                   5                14.0
# 3           1               1                   4                 9.0
# 4           1               0                   4                 5.0
#
#    Product_Category_3  Gender_F  Gender_M  Age_0-17  Age_18-25  Age_26-35  \
# 0           12.669454         0         1         0          0          0
# 1           12.669454         0         1         0          0          1
# 2           12.669454         1         0         0          0          0
# 3           12.669454         1         0         0          0          0
# 4           12.000000         1         0         0          0          1
#
#                ...                Age_51-55  Age_55+  City_Category_A  \
# ...

# %%
predicted3=clf.predict(test)

# %%
outdf=pd.DataFrame({"User_ID":a1,"Product_ID":b1,"Purchase":predicted3})
outdf.to_csv("BlackFridayGBR.csv")
